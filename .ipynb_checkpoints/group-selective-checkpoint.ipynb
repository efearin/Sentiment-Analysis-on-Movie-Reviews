# %%
import pandas as pd
df=pd.read_csv('data/train.csv',sep="\t")
#define group-selective save path
path='C:\\Users\\efear\\Documents\\GitHub\\Sentiment-Analysis-on-Movie-Reviews\\data\\group-selective\\'
print(df.head())
df.info()
print(df.describe())
print('---------------------------------------------------------------------------------------------')

#single words in df
onedf=df.copy(deep=True)
oneMask = onedf.Phrase.str.match(r'\A[\w-]+\Z')
onedf=onedf[oneMask]
print(onedf.head())
onedf.info()
print(onedf.describe())
onedf.to_csv(path+"onedf.csv", sep='\t')
print('---------------------------------------------------------------------------------------------')

#two words in df
twodf=df.copy(deep=True)
twoMask = twodf.Phrase.str.match(r'\A[\w-]+\s+[\w-]+\Z')
twodf=twodf[twoMask]
print(twodf.head())
twodf.info()
print(twodf.describe())
twodf.to_csv(path+"twodf.csv", sep='\t')
print('---------------------------------------------------------------------------------------------')

threedf=df.copy(deep=True)
threeMask = threedf.Phrase.str.match(r'\A[\w-]+\s+[\w-]+\s+[\w-]\Z')
threedf=threedf[threeMask]
print(threedf.head())
threedf.info()
print(threedf.describe())
threedf.to_csv(path+"threedf.csv", sep='\t')
print('---------------------------------------------------------------------------------------------')

fourdf=df.copy(deep=True)
fourMask = fourdf.Phrase.str.match(r'\A[\w-]+\s+[\w-]+\s+[\w-]\Z')
fourdf=fourdf[fourMask]
print(fourdf.head())
fourdf.info()
print(fourdf.describe())
fourdf.to_csv(path+"fourdf.csv", sep='\t')
print('---------------------------------------------------------------------------------------------')

fivedf=df.copy(deep=True)
fiveMask = fivedf.Phrase.str.match(r'\A[\w-]+\s+[\w-]+\s+[\w-]\Z')
fivedf=fivedf[fourMask]
print(fivedf.head())
fivedf.info()
print(fivedf.describe())
fivedf.to_csv(path+"fivedf.csv", sep='\t')
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
# PhraseId      156060 non-null int64
# SentenceId    156060 non-null int64
# Phrase        156060 non-null object
# Sentiment     156060 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB
#             PhraseId     SentenceId      Sentiment
# count  156060.000000  156060.000000  156060.000000
# mean    78030.500000    4079.732744       2.063578
# std     45050.785842    2502.764394       0.893832
# min         1.000000       1.000000       0.000000
# 25%     39015.750000    1861.750000       2.000000
# 50%     78030.500000    4017.000000       2.000000
# 75%    117045.250000    6244.000000       3.000000
# max    156060.000000    8544.000000       4.000000
# ---------------------------------------------------------------------------------------------
#     PhraseId  SentenceId         Phrase  Sentiment
# 3          4           1              A          2
# 4          5           1         series          2
# 6          7           1             of          2
# 8          9           1      escapades          2
# 11        12           1  demonstrating          2
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16371 entries, 3 to 156059
# Data columns (total 4 columns):
# PhraseId      16371 non-null int64
# SentenceId    16371 non-null int64
# Phrase        16371 non-null object
# Sentiment     16371 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 639.5+ KB
#             PhraseId    SentenceId     Sentiment
# count   16371.000000  16371.000000  16371.000000
# mean    58661.358866   3023.001649      2.003176
# std     45446.312007   2492.414509      0.579419
# min         4.000000      1.000000      0.000000
# 25%     17869.500000    776.000000      2.000000
# 50%     49016.000000   2393.000000      2.000000
# 75%     94903.500000   4952.000000      2.000000
# max    156060.000000   8544.000000      4.000000
# ---------------------------------------------------------------------------------------------
#     PhraseId  SentenceId      Phrase  Sentiment
# 2          3           1    A series          2
# 12        13           1   the adage          2
# 25        26           1   the goose          2
# 29        30           1     is also          2
# 35        36           1  the gander          2
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23602 entries, 2 to 156057
# Data columns (total 4 columns):
# PhraseId      23602 non-null int64
# SentenceId    23602 non-null int64
# Phrase        23602 non-null object
# Sentiment     23602 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 922.0+ KB
#             PhraseId    SentenceId     Sentiment
# count   23602.000000  23602.000000  23602.000000
# mean    76282.379502   3982.044911      2.083086
# std     44959.354389   2496.255011      0.682207
# min         3.000000      1.000000      0.000000
# 25%     37349.750000   1772.000000      2.000000
# 50%     75133.500000   3852.000000      2.000000
# 75%    114771.750000   6107.750000      2.000000
# max    156058.000000   8544.000000      4.000000
# ---------------------------------------------------------------------------------------------
#        PhraseId  SentenceId                            Phrase  Sentiment
# 6155       6156         245                    real bump-in -          2
# 8173       8174         338  highly-praised disappointments I          1
# 10389     10390         437                         more as a          2
# 12148     12149         520                    Santa Clause 2          2
# 12869     12870         553                   Stuart Little 2          2
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 6155 to 154863
# Data columns (total 4 columns):
# PhraseId      38 non-null int64
# SentenceId    38 non-null int64
# Phrase        38 non-null object
# Sentiment     38 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ KB
#             PhraseId   SentenceId  Sentiment
# count      38.000000    38.000000  38.000000
# mean    72291.026316  3763.157895   1.921053
# std     46555.158977  2580.803987   0.587325
# min      6156.000000   245.000000   1.000000
# 25%     27011.750000  1240.750000   2.000000
# 50%     78831.000000  4058.500000   2.000000
# 75%    106571.000000  5630.500000   2.000000
# max    154864.000000  8470.000000   3.000000
# ---------------------------------------------------------------------------------------------
#        PhraseId  SentenceId                            Phrase  Sentiment
# 6155       6156         245                    real bump-in -          2
# 8173       8174         338  highly-praised disappointments I          1
# 10389     10390         437                         more as a          2
# 12148     12149         520                    Santa Clause 2          2
# 12869     12870         553                   Stuart Little 2          2
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 6155 to 154863
# Data columns (total 4 columns):
# PhraseId      38 non-null int64
# SentenceId    38 non-null int64
# Phrase        38 non-null object
# Sentiment     38 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ KB
#             PhraseId   SentenceId  Sentiment
# count      38.000000    38.000000  38.000000
# mean    72291.026316  3763.157895   1.921053
# std     46555.158977  2580.803987   0.587325
# min      6156.000000   245.000000   1.000000
# 25%     27011.750000  1240.750000   2.000000
# 50%     78831.000000  4058.500000   2.000000
# 75%    106571.000000  5630.500000   2.000000
# max    154864.000000  8470.000000   3.000000
# ---------------------------------------------------------------------------------------------
#        PhraseId  SentenceId                            Phrase  Sentiment
# 6155       6156         245                    real bump-in -          2
# 8173       8174         338  highly-praised disappointments I          1
# 10389     10390         437                         more as a          2
# 12148     12149         520                    Santa Clause 2          2
# 12869     12870         553                   Stuart Little 2          2
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 6155 to 154863
# Data columns (total 4 columns):
# PhraseId      38 non-null int64
# SentenceId    38 non-null int64
# Phrase        38 non-null object
# Sentiment     38 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ KB
#             PhraseId   SentenceId  Sentiment
# count      38.000000    38.000000  38.000000
# mean    72291.026316  3763.157895   1.921053
# std     46555.158977  2580.803987   0.587325
# min      6156.000000   245.000000   1.000000
# 25%     27011.750000  1240.750000   2.000000
# 50%     78831.000000  4058.500000   2.000000
# 75%    106571.000000  5630.500000   2.000000
# max    154864.000000  8470.000000   3.000000
